# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression, LinearRegression
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /home/itush/miniconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %% [markdown]
# # <u>Q4

# %%
def get_rhc_data():
    df = pd.read_csv('../rhc.csv').set_index('index', drop=True)
    df = df[(df.treatment<2) & (df.female<2) & (df.meanbp1>0)].copy()  # drop the weird stuff
    return df
df = get_rhc_data()

# %% [markdown]
# ## <u>Model propensity score

# %% [markdown]
# ### Find decent features for the propensity score:

# %%
df.corr()['treatment'].sort_values()  # correlation between treatment and the different columns
# Out:
# meanbp1     -0.209216
# Coma        -0.105195
# Cirr        -0.066181
# female      -0.043671
# lungcan     -0.041828
# age         -0.031341
# ARF         -0.026441
# colcan      -0.017084
# MOSF         0.009245
# wtf          0.012505
# CHF          0.047845
# death        0.049868
# sepsis       0.204740
# treatment    1.000000
# Name: treatment, dtype: float64

# %%
df.corr()['sepsis']['meanbp1']  # correlation between sepsis & meanbp1
# Out:
# -0.13807546863595518

# %% [markdown]
# ### fit logit as propensity score

# %%
pi_params = ['sepsis', 'meanbp1']
pi_model = LogisticRegression(max_iter=500).fit(df[pi_params], df['treatment'].values.ravel())
df['propensity_score'] = pi_model.predict_proba(df[pi_params])[:,1]
df['propensity_score_err'] = df['treatment'] - df['propensity_score']
print('propensity model absolute error rate:', df['propensity_score_err'].abs().sum()/len(df))
df.loc[df['treatment']==1, 'w'] = df.loc[df['treatment']==1, 'propensity_score']
df.loc[df['treatment']==0, 'w'] = 1/(1-df.loc[df['treatment']==0, 'propensity_score'])
# Out:
# propensity model absolute error rate: 0.4346972323371597

# %%
sns.kdeplot(df[df.treatment==1].propensity_score, label='treatment')
sns.kdeplot(df[df.treatment==0].propensity_score, label='no treatment')
plt.legend()

# %%
def apply_w(row):
    if row.treatment == 1:
        return 1/row.propensity_score
    elif row.treatment == 0:
        return 1/(1-row.propensity_score)
    else:
        raise Exception("WTF")

df['w'] = df.apply(lambda row: apply_w(row), axis=1)

# %%
df['w'].hist(bins=10)
plt.title('Weights Histogram')
# Out:
# Text(0.5, 1.0, 'Weights Histogram')

# %% [markdown]
# Weights look reasonable.

# %%
W = df['w']
A = df['treatment']
Y = df['death']
n = len(df)
ATE_ITPW = sum(W*A*Y)/n - sum(W*(1-A)*Y)/n
ATE_ITPW
# Out:
# 0.03649582619905134

# %% [markdown]
# ## <u> Model mu

# %% [markdown]
# ### Find features for mu model:

# %%
df.corr()['death'].sort_values()  # correlation between death and the different columns
# Out:
# ARF                    -0.104839
# meanbp1                -0.100588
# CHF                    -0.028846
# female                 -0.019384
# wtf                    -0.017446
# sepsis                 -0.006347
# colcan                 -0.005622
# w                       0.022048
# Cirr                    0.023926
# propensity_score_err    0.033071
# lungcan                 0.047102
# treatment               0.049868
# propensity_score        0.065839
# Coma                    0.083111
# MOSF                    0.149264
# age                     0.215895
# death                   1.000000
# Name: death, dtype: float64

# %%
df.corr()['age']['MOSF']  # correlation between age and MOSF
# Out:
# -0.05623430840894392

# %% [markdown]
# ## Fit models for mu0 & mu1

# %%
y_params = ['age', 'MOSF']  # using the same parameters for both models out of lazyness
treatment = df[df['treatment']==1].copy()
control = df[df['treatment']==0].copy()

y1_model = LogisticRegression(max_iter=500).fit(treatment[y_params], treatment['death'].values.ravel())
treatment['y_score'] = y1_model.predict_proba(treatment[y_params])[:,1]
treatment['y_score_err'] = treatment['death'] - treatment['y_score']
print('y1 model absolute error rate:', treatment['y_score_err'].abs().sum()/len(df))

y0_model = LogisticRegression(max_iter=500).fit(control[y_params], control['death'].values.ravel())
control['y_score'] = y0_model.predict_proba(control[y_params])[:,1]
control['y_score_err'] = control['death'] - control['y_score']
print('y0 model absolute error rate:', control['y_score_err'].abs().sum()/len(df))

df['mu_0'] = y0_model.predict_proba(df[y_params])[:,1]
df['mu_1'] = y1_model.predict_proba(df[y_params])[:,1]
# Out:
# y1 model absolute error rate: 0.1540349303932069
# y0 model absolute error rate: 0.2672726735046269

# %%
sns.kdeplot(df.mu_1, label='treatment y model')
sns.kdeplot(df.mu_0, label='control y model')
plt.legend()

# %%
U0 = df['mu_0']
U1 = df['mu_1']
P = df['propensity_score']
dr_correction = sum( (A-P) * ( (U1/P) - (U0/(1-P) ))) / n
dr_correction
# Out:
# 0.0005985126610937297

# %%
ATE_DR = ATE_ITPW - dr_correction
print("The doubly-robust estimator for treatment effect in the RHC data calculated is:", ATE_DR)
# Out:
# The doubly-robust estimator for treatment effect in the RHC data calculated is: 0.03589731353795761

# %% [markdown]
# # <u>Q5 - C

# %% [markdown]
# # <u> Q6

# %% [markdown]
# # Q6 - A
# E[Y1]-E[Y0] = b1 <br>
# So.... yes!

# %% [markdown]
# # <U> Q6 - B - Simulate Data

# %%
def inverse_logit(x):
    return 1/(1+np.exp(-x))


def logit(x):
    return np.log(x/(1-x))


def plot_data(df):
    # plot IIDs
    sns.kdeplot(df['x'], label='X')
    sns.kdeplot(df['v'], label='V')
    plt.legend()
    plt.show()
    # plot Ys
    sns.kdeplot(df['y0'], label='y0')
    sns.kdeplot(df['y1'], label='y1')
    plt.legend()
    plt.xlabel('y')
    plt.show()
    # plot treatment
    sns.kdeplot(df['a_as_fraction'])
    plt.show()
    sns.scatterplot(data=df, x='x', y='a_as_fraction')
    plt.show()
    # plot observed
    sns.kdeplot(df[df['a']==1]['y'], label='A=1')
    sns.kdeplot(df[df['a']==0]['y'], label='A=0')
    plt.legend()
    plt.show()
    
    
def simulate_data(plot=False, sample_size=500, with_interaction=False):
    # define params
    b0 = 100
    b1 = 2
    b2 = 3.5
    b3 = 5
    epsilon_std = 3
    c0 = logit(0.2)
    c1 = np.log(2)
    b4 = 1
    df = pd.DataFrame()
    # create data
    df['x'] = np.random.normal(0, 1, size=sample_size)
    df['v'] = np.random.normal(0, 1, size=sample_size)
    df['e'] = np.random.normal(0, epsilon_std, size=sample_size)
    df['y0'] = b0 + b2*df['x'] + b3*df['v'] + df['e']
    df['y1'] = b0 + b1 + b2*df['x'] + b3*df['v'] + df['e']
    df['a_as_fraction'] = inverse_logit(c0 + c1*df['x'])
    df['a'] = round(df['a_as_fraction'])
    if with_interaction:
        df['av'] = df['a'] * df['v']
        df['y0'] += b4*df['av']
        df['y1'] += b4*df['av']
    df['y'] = df.apply(lambda row: row['y1'] if row['a']==1 else row['y0'], axis=1)
    if plot:
        plot_data(df)
    return df

# %%
df = simulate_data(plot=True)
df
# Out:
#             x         v         e          y0          y1  a_as_fraction    a  \
# 0   -0.031334 -0.292624  4.591793  103.019000  105.019000       0.196548  0.0
# 1   -0.350421 -0.438520  2.646148   99.227075  101.227075       0.163942  0.0
# 2    0.771579  0.484219  1.190556  106.312176  108.312176       0.299123  0.0
# 3    1.400948 -0.093782 -0.878937  103.555472  105.555472       0.397658  0.0
# 4    2.507660 -1.736882  2.329496  102.421894  104.421894       0.587074  1.0
# ..        ...       ...       ...         ...         ...            ...  ...
# 495  0.934686 -0.514677 -0.577693  100.120324  102.120324       0.323350  0.0
# 496  1.164517 -0.460261 -0.395768  101.378737  103.378737       0.359137  0.0
# 497 -1.333905  0.419099 -0.906380   96.520446   98.520446       0.090225  0.0
# 498 -0.795864  0.176473  2.278923  100.375766  102.375766       0.125874  0.0
# 499  0.040024 -1.136897  2.351680   96.807277   98.807277       0.204476  0.0
#
#               y
# 0    103.019000
# 1     99.227075
# 2    106.312176
# 3    103.555472
# 4    104.421894
# ..          ...
# 495  100.120324
# 496  101.378737
# 497   96.520446
# 498  100.375766
# 499   96.807277
#
# [500 rows x 8 columns]

# %% [markdown]
# # <u> Q6 - C

# %%
def calculate_naive_ATE(df):
    avg_y_grouped_by_a = df.groupby('a')['y'].mean()
    naive_ATE = avg_y_grouped_by_a[1] - avg_y_grouped_by_a[0]
    return naive_ATE

    
def calculate_pi(df):
    # simple logistic regression based on X
    df = df.copy()
    pi_model = LogisticRegression(max_iter=500).fit(df[['x']], df['a'].values.ravel())
    df['pi'] = pi_model.predict_proba(df[['x']])[:,1]
    return df


def create_matched_dataset(df):
    treatment = df[df['a']==1]
    control = df[df['a']==0].copy()
    control.columns += '_control'
    rows = []
    for treatment_index, treatment_row in treatment.iterrows():
        control_index = abs(treatment_row['pi']-control['pi_control']).idxmin()
        control_row = control.loc[control_index]
        control.drop(control_index, inplace=True)
        rows.append(pd.concat([treatment_row, control_row]))
    matched = pd.DataFrame.from_records(rows)
    return matched


def calc_LR_intercept(data, confounders, outcome):
    model = LinearRegression()
    model.fit(data[confounders], data[outcome].values.ravel())
    return model.intercept_ 


def calc_LR_intercept_and_interaction(data, confounders, outcome):
    model = LinearRegression()
    model.fit(data[confounders], data[outcome].values.ravel())
    b4 = model.coef_[2]
    return model.intercept_ ,b4


def estimate_ATT_matched_with_lr(matched, with_interaction):
    # we'll be running LR on the differences between matched pairs
    # so, Y1-Y0 ~ X1-X0 --> the intercept will be our estimation for the ATT
    matched_diffs = pd.DataFrame()  
    for col in [x for x in matched.columns if '_' not in x]:
        matched_diffs[col] = matched[col] - matched[col+'_control']
    ATT_X = calc_LR_intercept(data=matched_diffs, confounders=['x'], outcome='y')
    ATT_XV = calc_LR_intercept(data=matched_diffs, confounders=['x','v'], outcome='y')
    ATT_XVAV = ATT_V_interaction = None
    if with_interaction:
        ATT_XVAV, ATT_V_interaction = calc_LR_intercept_and_interaction(
            data=matched_diffs, confounders=['x','v','av'], outcome='y')
    return ATT_X, ATT_XV, ATT_XVAV, ATT_V_interaction

    

def simulate_datasets(num_of_datasets, sample_size=500, with_interaction=False):
    results = []
    for i in range(num_of_datasets):
        df = simulate_data(sample_size=sample_size, with_interaction=with_interaction)
        naive_ATE = calculate_naive_ATE(df)
        df = calculate_pi(df)
        matched = create_matched_dataset(df)
        naive_ATT = np.mean(matched['y'] - matched['y_control'])
        ATT_X, ATT_XV, ATT_XVAV, ATT_V_interaction = estimate_ATT_matched_with_lr(matched, with_interaction)
        results.append({'naive_ATE': naive_ATE, 'naive_ATT': naive_ATT, 'b0_inference_by_X': ATT_X, 
                        'b0_inference_by_X&V': ATT_XV,
                        'b0_inference_by_X&V&AV': ATT_XVAV, 'b4': ATT_V_interaction})
    results_df = pd.DataFrame.from_records(results)
    return results_df.describe().loc[['mean','std']]

# %%
def calc_LR(data, confounders, outcome):
    model = LinearRegression()
    model.fit(data[confounders], data[outcome].values.ravel())
    return np.append(model.intercept_, model.coef_)


def estimate_ATT_matched_with_lr(matched, with_interaction):
    ATT_X = calc_LR(data=matched, confounders=['x','a'], outcome='y')
    ATT_XV = calc_LR(data=matched, confounders=['x','a','v'], outcome='y')
    ATT_XVAV = ATT_V_interaction = None
    if with_interaction:
        ATT_XVAV = calc_LR(data=matched, confounders=['x','a','v','av'], outcome='y')
    return ATT_X, ATT_XV, ATT_XVAV


def create_matched_dataset(df):
    treatment = df[df['a']==1]
    control = df[df['a']==0].copy()
    control.columns += '_control'
    indices = []
    for treatment_index, treatment_row in treatment.iterrows():
        control_index = abs(treatment_row['pi']-control['pi_control']).idxmin()
        control.drop(control_index, inplace=True)
        indices.append(control_index)
        indices.append(treatment_index)
    matched = df.loc[indices,:].copy()
    return matched



def simulate_datasets(num_of_datasets, sample_size=500, with_interaction=False):
    results = []
    for i in range(num_of_datasets):
        df = simulate_data(sample_size=sample_size, with_interaction=with_interaction)
        naive_ATE = calculate_naive_ATE(df)
        df = calculate_pi(df)
        matched = create_matched_dataset(df)
        naive_ATT = None
        ATT_X, ATT_XV, XVA = estimate_ATT_matched_with_lr(matched, with_interaction)
        results.append({'naive_ATE': naive_ATE, 'naive_ATT': naive_ATT, 'ATTX0': ATT_X[0], 'ATTX1': ATT_X[1],
                        'ATTX2': ATT_X[2], 'ATTXV0': ATT_XV[0], 'ATTXV1': ATT_XV[1], 'ATTXV2': ATT_XV[2],
                        'ATTXV3': ATT_XV[3], 'XVA0': XVA[0], 'XVA1': XVA[1], 'XVA2': XVA[2],
                        'XVA3': XVA[3], 'XVA4': XVA[4]})
    results_df = pd.DataFrame.from_records(results)
    return results_df.describe().loc[['mean','std']]

# %% [markdown]
# # <u> Q6 - D

# %%
simulate_datasets(num_of_datasets=1000, sample_size=500)
# Out:
#       naive_ATE      ATTX0     ATTX1     ATTX2      ATTXV0    ATTXV1  \
# mean  10.436680  99.400641  3.860928  1.756944  100.178527  3.402655
# std    1.890081  13.350563  7.178019  4.289852    7.896189  4.236525
#
#         ATTXV2    ATTXV3
# mean  2.009913  4.988319
# std   2.321141  0.945693

# %%
simulate_datasets(num_of_datasets=1000, sample_size=500)
# Out:
#       naive_ATE  naive_ATT     ATT_X    ATT_XV
# mean  10.466112   3.871575  2.064077  1.961030
# std    1.885842   2.672420  5.793823  3.213584

# %% [markdown]
# - Looks like both naive methods have a low variance but are biased.
# - Conversely, the ATT regression methods are not biased but suffer from high variance.
# - Using both X & V in the regression reduced biased dramatically but it is still very high...
# - That being said, it is not very surprising the variance is high as in the current setup the matched dataset is made of about 10 pairs...
# - Despite the treated population being very small and biased towards high X values, the ATT seems to equal the ATE but with very high variance.

# %% [markdown]
# # <u> Q6 - E

# %%
simulate_datasets(num_of_datasets=1000, sample_size=2500)
# Out:
#       naive_ATE       ATTX0     ATTX1     ATTX2      ATTXV0    ATTXV1  \
# mean  10.458954  100.101086  3.432970  2.014513  100.096823  3.450519
# std    0.835588    4.402746  2.367116  1.684935    2.269783  1.229624
#
#         ATTXV2    ATTXV3
# mean  2.015512  5.004198
# std   0.890918  0.294705

# %%
simulate_datasets(num_of_datasets=1000, sample_size=2500)
# Out:
#       naive_ATE  naive_ATT     ATT_X    ATT_XV
# mean  10.471715   3.892749  1.994744  1.983481
# std    0.803219   1.125412  2.174563  1.072825

# %% [markdown]
# - As expected, by using more data all the estimators got lower variance and no change in the bias.
# - The variance of the regression estimators is still disappointedly high...

# %% [markdown]
# # <U> Q6 - F

# %%
simulate_datasets(num_of_datasets=1000, sample_size=500, with_interaction=True)
# Out:
#       naive_ATE      ATTX0     ATTX1     ATTX2     ATTXV0    ATTXV1    ATTXV2  \
# mean  10.482087  99.769701  3.646121  1.925609  99.535625  3.753262  1.870619
# std    2.118960  15.270691  8.180090  4.867219   7.717710  4.131372  2.334022
#
#         ATTXV3       XVA0      XVA1      XVA2      XVA3      XVA4
# mean  5.457173  99.579202  3.732815  1.866089  5.003856  0.997765
# std   0.807843   8.144917  4.353580  2.401607  1.172849  1.741722

# %%
simulate_datasets(num_of_datasets=1000, sample_size=500, with_interaction=True)
# Out:
#       naive_ATE  naive_ATT  b0_inference_by_X  b0_inference_by_X&V  \
# mean  10.540441   3.998437           2.109104             2.090360
# std    2.130456   2.820854           5.978423             3.188565
#
#       b0_inference_by_X&V&AV        b4
# mean                2.116046  0.896823
# std                 4.159815  5.605760

# %%
simulate_datasets(num_of_datasets=1000, sample_size=2500, with_interaction=True)
# Out:
#       naive_ATE      ATTX0     ATTX1     ATTX2     ATTXV0    ATTXV1    ATTXV2  \
# mean  10.495925  99.858489  3.595834  1.909811  99.925120  3.540311  1.975541
# std    0.891883   4.795687  2.573383  1.805308   2.283481  1.214398  0.857592
#
#         ATTXV3       XVA0      XVA1      XVA2      XVA3      XVA4
# mean  5.489996  99.923588  3.541707  1.973324  5.002398  0.986905
# std   0.288915   2.255307  1.200503  0.855535  0.411301  0.571005

# %%
simulate_datasets(num_of_datasets=1000, sample_size=2500, with_interaction=True)
# Out:
#       naive_ATE  naive_ATT     ATT_X    ATT_XV  ATT_XVAV  ATT_V_interaction
# mean  10.527580   3.934116  2.044893  2.031948  2.032675           0.952453
# std    0.899773   1.186375  2.239935  1.123645  1.103802           0.871623

# %% [markdown]
# ## What have learned:
# - Using matching to appproximate the ATT be representitive of ATE.
# - Adding an interaction term may not reduce variance even if it is correctly specified. (wtf?)
# - Greater sample size reduces variance (duh).
# - Matching is FUN!

# %% [markdown]
# # <U> Q7
